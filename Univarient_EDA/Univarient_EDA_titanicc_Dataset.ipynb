# %% [markdown]
# ## Univarient data analysis means single variable/column ka analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 524          525         0       3               Kassem, Mr. Fared  male
# 626          627         0       2  Kirkland, Rev. Charles Leonard  male
# 619          620         0       2             Gavey, Mr. Lawrence  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 524   NaN      0      0    2700   7.2292   NaN        C
# 626  57.0      0      0  219533  12.3500   NaN        Q
# 619  26.0      0      0   31028  10.5000   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 1 Catagorial Data

# %% [markdown]
# ## 1a) Count Plot

# %%
sns.countplot(data=df,x='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
ax=sns.countplot(data=df,x='Pclass')
# Display the count values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

# %% [markdown]
# # 1b) pie Chart

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Pclass'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
plt.hist(data=df,x="Age")
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\HAMZA ABBAS\AppData\Local\Temp\ipykernel_9652\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Diskplot

# %%
sns.displot(data=df, x='Age', kde=True)

# %%
count_20_age = df[df['Age'] == 20].shape[0]

# %%
count_20_age
# Out:
# 15

# %%
# Count the number of people with age equal to 20
count_20_age = df[df['Age'] == 20].shape[0]

# Create a bar plot
plt.figure(figsize=(6, 4))
ax =sns.barplot(x=['Age 20'], y=[count_20_age])
# Display the count values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.title('Number of People with Age 20')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ## Box_Plot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %% [markdown]
# # Working with Another Data

# %%
df1 = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df1.sample(3)
# Out:
#          id           city        date player_of_match  \
# 445  734025     Chandigarh  2014-05-21     LMP Simmons
# 563  980993  Visakhapatnam  2016-05-15       KH Pandya
# 194  501218         Mumbai  2011-04-20        MM Patel
#
#                                                  venue  neutral_venue  \
# 445         Punjab Cricket Association Stadium, Mohali              0
# 563  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              0
# 194                                   Wankhede Stadium              0
#
#                team1             team2       toss_winner toss_decision  \
# 445  Kings XI Punjab    Mumbai Indians    Mumbai Indians         field
# 563   Mumbai Indians  Delhi Daredevils  Delhi Daredevils         field
# 194   Mumbai Indians     Pune Warriors     Pune Warriors           bat
#
#              winner   result  result_margin eliminator method  \
# 445  Mumbai Indians  wickets            7.0          N    NaN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
city_counts = df1['city'].value_counts().head(10)

# %%
city_counts
# Out:
# Mumbai        101
# Kolkata        77
# Delhi          74
# Bangalore      65
# Hyderabad      64
# Chennai        57
# Chandigarh     56
# Jaipur         47
# Pune           38
# Abu Dhabi      29
# Name: city, dtype: int64

# %%
plt.figure(figsize=(10, 6))
ax=sns.barplot(data=df1, x=city_counts.index, order=city_counts.index, y=city_counts.values)
# Display the count values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.xlabel('City')
plt.ylabel('Number of Matches')
plt.title('Top 10 Cities with Most Matches Played')

plt.tight_layout()
plt.show()

# %%
df1['result'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\HAMZA ABBAS\AppData\Local\Temp\ipykernel_9652\573703546.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Create a plot
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', hue='Sex', multiple='stack', bins=20)
plt.title('Survival Analysis by Age and Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the Titanic dataset
titanic_data = pd.read_csv('train.csv')  # Replace with the actual path

# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Plot 1: Survival Rate by Gender
sns.barplot(x='Sex', y='Survived', data=titanic_data, ax=axes[0, 0])
axes[0, 0].set_title('Survival Rate by Gender')

# Plot 2: Survival Rate by Passenger Class
sns.barplot(x='Pclass', y='Survived', data=titanic_data, ax=axes[0, 1])
axes[0, 1].set_title('Survival Rate by Passenger Class')

# Plot 3: Age Distribution
sns.histplot(data=titanic_data, x='Age', bins=20, ax=axes[0, 2])
axes[0, 2].set_title('Age Distribution')

# Plot 4: Fare Distribution
sns.histplot(data=titanic_data, x='Fare', bins=20, ax=axes[1, 0])
axes[1, 0].set_title('Fare Distribution')

# Plot 5: Embarkation Port Distribution
sns.countplot(x='Embarked', data=titanic_data, ax=axes[1, 1])
axes[1, 1].set_title('Embarkation Port Distribution')

# Plot 6: Survival Rate by Embarkation Port
sns.barplot(x='Embarked', y='Survived', data=titanic_data, ax=axes[1, 2])
axes[1, 2].set_title('Survival Rate by Embarkation Port')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
