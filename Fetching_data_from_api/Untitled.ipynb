# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 121.035,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 18437},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 121.035,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 18437},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
df =pd.DataFrame(response.json()['results'])[['id','title','original_title','overview','release_date','vote_average','vote_count']]

# %%
df.sample(5)
# Out:
#        id                        title                original_title  \
# 4   19404  Dilwale Dulhania Le Jayenge  दिलवाले दुल्हनिया ले जायेंगे
# 1     278     The Shawshank Redemption      The Shawshank Redemption
# 17  11216              Cinema Paradiso         Nuovo Cinema Paradiso
# 11    680                 Pulp Fiction                  Pulp Fiction
# 0     238                The Godfather                 The Godfather
#
#                                              overview release_date  \
# 4   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1   Framed in the 1940s for the double murder of h...   1994-09-23
# 17  A filmmaker recalls his childhood, when he fel...   1988-11-17
# 11  A burger-loving hit man, his philosophical par...   1994-09-10
# 0   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
#
#     vote_average  vote_count
# 4            8.6        4219
# 1            8.7       24361
# 17           8.5        3891
# ...

# %%
df1 =pd.DataFrame()

# %%
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,568):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}')

    temp_df =pd.DataFrame(response.json()['results'])[['id','title','original_title','overview','release_date','vote_average','vote_count']]
    
    concatenated_df = pd.concat([df1, temp_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 4
#       1 for i in range(1,568):
#       2     response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}')
# ----> 4     temp_df =pd.DataFrame(response.json()['results'])[['id','title','original_title','overview','release_date','vote_average','vote_count']]
#       6     concatenated_df = pd.concat([df1, temp_df], ignore_index=True)
#
# KeyError: 'results'

# %%
concatenated_df
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4    19404                    Dilwale Dulhania Le Jayenge
# 5      129                                  Spirited Away
# 6      389                                   12 Angry Men
# 7   372058                                     Your Name.
# 8   496243                                       Parasite
# 9      155                                The Dark Knight
# 10     497                                 The Green Mile
# 11     680                                   Pulp Fiction
# 12      13                                   Forrest Gump
# 13     122  The Lord of the Rings: The Return of the King
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
concatenated_df.shape
# Out:
# (20, 7)

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,568):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\HAMZA ABBAS\AppData\Local\Temp\ipykernel_6840\4037229190.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\HAMZA ABBAS\AppData\Local\Temp\ipykernel_6840\4037229190.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\HAMZA ABBAS\AppData\Local\Temp\ipykernel_6840\4037229190.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\HAMZA ABBAS\AppData\Local\Temp\ipykernel_6840\4037229190.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
import requests
import pandas as pd

df = pd.DataFrame(columns=['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count'])

for i in range(1, 568):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    response_json = response.json()

    if 'results' in response_json:
        temp_df = pd.DataFrame(response_json['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
        df = pd.concat([df, temp_df], ignore_index=True)
    else:
        print(f"No 'results' key found in response for page {i}")

# Now you have the concatenated DataFrame
# Out:
# No 'results' key found in response for page 501
# No 'results' key found in response for page 502
# No 'results' key found in response for page 503
# No 'results' key found in response for page 504
# No 'results' key found in response for page 505
# No 'results' key found in response for page 506
# No 'results' key found in response for page 507
# No 'results' key found in response for page 508
# No 'results' key found in response for page 509
# No 'results' key found in response for page 510
# No 'results' key found in response for page 511
# No 'results' key found in response for page 512
# No 'results' key found in response for page 513
# No 'results' key found in response for page 514
# No 'results' key found in response for page 515
# No 'results' key found in response for page 516
# No 'results' key found in response for page 517
# No 'results' key found in response for page 518
# No 'results' key found in response for page 519
# No 'results' key found in response for page 520
# ...

# %%
df
# Out:
#           id                        title  \
# 0        238                The Godfather
# 1        278     The Shawshank Redemption
# 2        240        The Godfather Part II
# 3        424             Schindler's List
# 4      19404  Dilwale Dulhania Le Jayenge
# ...      ...                          ...
# 9995  254302                    High-Rise
# 9996   86834                         Noah
# 9997   11547                  Cabin Fever
# 9998    5552                     Immortal
# 9999  336011                   White Girl
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10000 non-null  object
#  1   title         10000 non-null  object
#  2   overview      10000 non-null  object
#  3   release_date  10000 non-null  object
#  4   popularity    10000 non-null  float64
#  5   vote_average  10000 non-null  float64
#  6   vote_count    10000 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 547.0+ KB
