# %%
import pandas as pd

# %%
df = pd.read_csv('aug_train.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
df2 = pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'],index_col='sno')

# %%
df2
# Out:
#                             name release_year  rating     votes  \
# sno
# m0    10 things i hate about you         1999     6.9   62847.0
# m1    1492: conquest of paradise         1992     6.2   10421.0
# m2                    15 minutes         2001     6.1   25854.0
# m3         2001: a space odyssey         1968     8.4  163227.0
# m4                       48 hrs.         1982     6.9   22289.0
# ...                          ...          ...     ...       ...
# m612                    watchmen         2009     7.8  135229.0
# m613                         xxx         2002     5.6   53505.0
# m614                       x-men         2000     7.4  122149.0
# m615          young frankenstein         1974     8.0   57618.0
# m616                   zulu dawn         1979     6.4    1911.0
#
#                                                  genres
# sno
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# ...

# %%
df2.tail(10)
# Out:
#                          name release_year  rating     votes  \
# sno
# m607           wild wild west         1999     4.3   54943.0
# m608                   willow         1988     7.1   33506.0
# m609                  witness         1985     7.6   30705.0
# m610         the wizard of oz         1939     8.3  104873.0
# m611  the world is not enough         1999     6.3   60047.0
# m612                 watchmen         2009     7.8  135229.0
# m613                      xxx         2002     5.6   53505.0
# m614                    x-men         2000     7.4  122149.0
# m615       young frankenstein         1974     8.0   57618.0
# m616                zulu dawn         1979     6.4    1911.0
#
#                                                  genres
# sno
# m607             ['action' 'western' 'comedy' 'sci-fi']
# m608  ['action' 'adventure' 'drama' 'fantasy' 'roman...
# m609                     ['drama' 'romance' 'thriller']
# m610         ['adventure' 'family' 'fantasy' 'musical']
# ...

# %%
df3 = pd.read_csv('test.csv',header=1,index_col='enrollee_id',usecols=['enrollee_id','gender','education_level','experience',])

# %%
df3
# Out:
#             gender education_level experience
# enrollee_id
# 29725         Male        Graduate         15
# 11561          NaN        Graduate          5
# 33241          NaN        Graduate         <1
# 666           Male         Masters        >20

# %%
df3.shape
# Out:
# (4, 3)

# %%
enrol =df['enrollee_id']

# %%
enrol
# Out:
# 0         8949
# 1        29725
# 2        11561
# 3        33241
# 4          666
#          ...
# 19153     7386
# 19154    31398
# 19155    24576
# 19156     5756
# 19157    23834
# Name: enrollee_id, Length: 19158, dtype: int64

# %%
df4 = pd.read_csv('aug_train.csv',skiprows=[0,5])

# %%
df4
# Out:
#         8949  city_103   0.92  Male  Has relevent experience  \
# 0      29725   city_40  0.776  Male   No relevent experience
# 1      11561   city_21  0.624   NaN   No relevent experience
# 2      33241  city_115  0.789   NaN   No relevent experience
# 3      21651  city_176  0.764   NaN  Has relevent experience
# 4      28806  city_160  0.920  Male  Has relevent experience
# ...      ...       ...    ...   ...                      ...
# 19151   7386  city_173  0.878  Male   No relevent experience
# 19152  31398  city_103  0.920  Male  Has relevent experience
# 19153  24576  city_103  0.920  Male  Has relevent experience
# 19154   5756   city_65  0.802  Male  Has relevent experience
# 19155  23834   city_67  0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM  >20 Unnamed: 9  \
# 0         no_enrollment        Graduate             STEM   15      50-99
# 1      Full time course        Graduate             STEM    5        NaN
# ...

# %%
pd.read_csv('aug_train.csv',dtype={'target':int})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df5=pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date'],converters={'team1':rename},na_values=["RCB"])

# %%
df5
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
def rename(name):
    if name =='Royal Challengers Bangalore':
        return 'RCB'
    if name =='Kings XI Punjab':
        return 'Hamza'
    else:
        return name

# %%
rename('Kings XI Punjab')
# Out:
# 'Hamza'

# %%
df6=pd.read_csv('IPL Matches 2008-2020.csv',na_values='field')

# %%
df6
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...
